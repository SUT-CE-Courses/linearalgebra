# %% [markdown]
# # Change of Basis, Eigenvalues & Diagonalization
#
# **Instructions:**
# - Complete all TODO sections
# - Do NOT use `np.linalg.eig` unless explicitly allowed
# - Show your work and verify results

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]

# %% [markdown]
# ---
# ## Part 1: Change of Basis (30 points)
#
# ### Problem 1.1 (10 points)
#
# Given two bases for $\mathbb{R}^2$:
#
# **Basis $B$:**
# $$\vec{b_1} = \begin{bmatrix} 3 \\ 1 \end{bmatrix}, \quad \vec{b_2} = \begin{bmatrix} 1 \\ 2 \end{bmatrix}$$
#
# **Basis $C$:**
# $$\vec{c_1} = \begin{bmatrix} 2 \\ -1 \end{bmatrix}, \quad \vec{c_2} = \begin{bmatrix} 1 \\ 3 \end{bmatrix}$$
#
# A vector has coordinates $[\vec{v}]_B = \begin{bmatrix} 2 \\ -1 \end{bmatrix}$ in basis $B$.
#
# **Find:**
# 1. The standard coordinates of $\vec{v}$
# 2. The coordinates $[\vec{v}]_C$ in basis $C$
# 3. The change of basis matrix $P_{B \to C}$ that converts directly from $B$ to $C$

# %%
# Define the bases
b1 = np.array([3, 1])
b2 = np.array([1, 2])
c1 = np.array([2, -1])
c2 = np.array([1, 3])

v_B = np.array([2, -1])  # coordinates in basis B

# TODO: Find v in standard coordinates
v_standard = None

# TODO: Find v in basis C
v_C = None

# TODO: Find P_{B->C} (direct conversion matrix)
P_B_to_C = None

# Verify: P_{B->C} @ v_B should equal v_C
print(f"v in standard: {v_standard}")
print(f"v in basis C: {v_C}")
print(f"P_{{B->C}}:\n{P_B_to_C}")

# %% [markdown]
# ### Problem 1.2 (10 points)
#
# Implement a general function `change_basis(v, from_basis, to_basis)` that converts coordinates between ANY two bases.
#
# **Requirements:**
# - Works for any dimension (2D, 3D, nD)
# - Handle the case when bases are not orthonormal
# - Raise an error if bases are not valid (singular matrix)

# %%
def change_basis(v, from_basis, to_basis):
    """
    Convert vector coordinates from one basis to another.

    Parameters:
    -----------
    v : np.array - coordinates in from_basis
    from_basis : list of np.array - source basis vectors
    to_basis : list of np.array - target basis vectors

    Returns:
    --------
    np.array - coordinates in to_basis
    """
    # TODO: Implement this function
    pass

# Test with Problem 1.1
result = change_basis(v_B, [b1, b2], [c1, c2])
print(f"Result: {result}")
print(f"Matches v_C? {np.allclose(result, v_C)}")

# %% [markdown]
# ### Problem 1.3 (10 points)
#
# Given a linear transformation $T: \mathbb{R}^2 \to \mathbb{R}^2$ represented by matrix $A$ in standard basis:
#
# $$A = \begin{bmatrix} 5 & 3 \\ 3 & 5 \end{bmatrix}$$
#
# **Find:**
# 1. The matrix $[T]_B$ representing $T$ in basis $B = \{\begin{bmatrix} 1 \\ 1 \end{bmatrix}, \begin{bmatrix} 1 \\ -1 \end{bmatrix}\}$
# 2. What is special about $[T]_B$? Why?
# 3. Verify by computing $T(\vec{b_1})$ both ways

# %%
A = np.array([[5, 3],
              [3, 5]])

B_basis = [np.array([1, 1]), np.array([1, -1])]

# TODO: Find [T]_B
T_B = None

print(f"[T]_B =\n{T_B}")

# TODO: Verify by computing T(b1)

# %% [markdown]
# ---
# ## Part 2: Eigenvalues & Eigenvectors (35 points)
#
# ### Problem 2.1 (15 points)
#
# Implement eigenvalue computation **from scratch** for a 2×2 matrix.
#
# **Do NOT use `np.linalg.eig`**
#
# Given:
# $$A = \begin{bmatrix} a & b \\ c & d \end{bmatrix}$$
#
# The characteristic polynomial is:
# $$\lambda^2 - (a+d)\lambda + (ad-bc) = 0$$

# %%
def eigenvalues_2x2(A):
    """
    Compute eigenvalues of a 2x2 matrix using the characteristic polynomial.
    Handle complex eigenvalues properly.

    Returns: tuple (lambda1, lambda2)
    """
    # TODO
    pass

def eigenvector_2x2(A, eigenvalue):
    """
    Compute the eigenvector for a given eigenvalue.
    Return a normalized eigenvector.

    Returns: np.array (normalized eigenvector)
    """
    # TODO
    pass

# Test matrices
test_matrices = [
    np.array([[4, 2], [1, 3]]),      # Real distinct eigenvalues
    np.array([[3, 0], [0, 3]]),      # Repeated eigenvalue
    np.array([[0, -1], [1, 0]]),     # Complex eigenvalues (rotation)
]

for i, A in enumerate(test_matrices):
    print(f"\nMatrix {i+1}:")
    print(A)

    my_eigs = eigenvalues_2x2(A)
    np_eigs = np.linalg.eigvals(A)

    print(f"My eigenvalues: {my_eigs}")
    print(f"NumPy eigenvalues: {np_eigs}")

# %% [markdown]
# ### Problem 2.2 (10 points)
#
# For the matrix:
# $$M = \begin{bmatrix} 2 & 1 & 0 \\ 0 & 2 & 1 \\ 0 & 0 & 3 \end{bmatrix}$$
#
# 1. Find ALL eigenvalues (you may use `np.linalg.eigvals`)
# 2. For each eigenvalue, determine its **algebraic multiplicity** (from characteristic polynomial)
# 3. For each eigenvalue, determine its **geometric multiplicity** (dimension of eigenspace)
# 4. Is this matrix diagonalizable? Why or why not?

# %%
M = np.array([[2, 1, 0],
              [0, 2, 1],
              [0, 0, 3]])

# TODO: Find eigenvalues
eigenvalues = None

# TODO: For each unique eigenvalue, find:
# - Algebraic multiplicity
# - Geometric multiplicity

# TODO: Answer: Is M diagonalizable?

# %% [markdown]
# ### Problem 2.3 (10 points)
#
# **Visualization:** Create a function that visualizes how a matrix transforms the unit circle, highlighting eigenvectors.
#
# Requirements:
# - Draw the unit circle and its transformation
# - Draw eigenvectors before and after transformation
# - Show that eigenvectors only get scaled (not rotated)

# %%
def visualize_eigen_transformation(A):
    """
    Visualize how matrix A transforms the unit circle.
    Highlight eigenvectors and show they only get scaled.
    """
    # TODO: Implement visualization
    # 1. Create unit circle points
    # 2. Transform circle with A
    # 3. Get eigenvectors and eigenvalues
    # 4. Plot: original circle, transformed ellipse, eigenvectors before/after
    pass

# Test with different matrices
A1 = np.array([[3, 1], [0, 2]])  # Upper triangular
A2 = np.array([[2, 1], [1, 2]])  # Symmetric

visualize_eigen_transformation(A1)
visualize_eigen_transformation(A2)

# %% [markdown]
# ---
# ## Part 3: Diagonalization (35 points)
#
# ### Problem 3.1 (15 points)
#
# Implement a complete `diagonalize(A)` function that:
# 1. Computes eigenvalues and eigenvectors
# 2. Returns $P$, $D$, $P^{-1}$ such that $A = PDP^{-1}$
# 3. Raises an appropriate error if matrix is not diagonalizable
#
# **You may use `np.linalg.eig` for this problem.**

# %%
def diagonalize(A, tol=1e-10):
    """
    Diagonalize matrix A.

    Returns:
    --------
    P, D, P_inv such that A = P @ D @ P_inv

    Raises:
    -------
    ValueError if matrix is not diagonalizable
    """
    # TODO: Implement diagonalization
    # Check if P is invertible
    pass

# Test
A = np.array([[4, 1],
              [2, 3]])

P, D, P_inv = diagonalize(A)

print("P =")
print(P)
print("\nD =")
print(D)
print("\nVerification: A = P @ D @ P^(-1)?")
print(np.allclose(A, P @ D @ P_inv))

# %% [markdown]
# ### Problem 3.2 (10 points)
#
# Using diagonalization, compute $A^{100}$ for:
#
# $$A = \begin{bmatrix} 1 & 2 \\ 0 & 3 \end{bmatrix}$$
#
# **Show your work:**
# 1. Find $P$, $D$, $P^{-1}$
# 2. Compute $D^{100}$
# 3. Compute $A^{100} = P D^{100} P^{-1}$
# 4. Verify with `np.linalg.matrix_power`

# %%
A = np.array([[1, 2],
              [0, 3]])

# TODO: Compute A^100 using diagonalization

A_100_numpy = np.linalg.matrix_power(A, 100)
print(f"A^100 (numpy) =\n{A_100_numpy}")

# %% [markdown]
# ### Problem 3.3 (10 points) - Fibonacci Challenge
#
# The Fibonacci sequence satisfies:
# $$\begin{bmatrix} F_{n+1} \\ F_n \end{bmatrix} = \begin{bmatrix} 1 & 1 \\ 1 & 0 \end{bmatrix} \begin{bmatrix} F_n \\ F_{n-1} \end{bmatrix}$$
#
# **Tasks:**
# 1. Diagonalize the Fibonacci matrix
# 2. Derive a **closed-form formula** for $F_n$ (Binet's formula)
# 3. Implement `fibonacci(n)` using matrix diagonalization
# 4. Compare speed with recursive implementation for large $n$

# %%
F_matrix = np.array([[1, 1],
                     [1, 0]])

# TODO: Diagonalize F_matrix

def fibonacci_matrix(n):
    """
    Compute F_n using matrix diagonalization.
    Should work for large n without overflow issues.
    """
    # TODO: Implement
    pass

def fibonacci_binet(n):
    """
    Compute F_n using Binet's formula derived from diagonalization.
    F_n = (φ^n - ψ^n) / √5
    """
    # TODO: Implement
    pass

# Test
print("n\tMatrix\tBinet")
for n in [0, 1, 5, 10, 20, 50]:
    f_mat = fibonacci_matrix(n)
    f_bin = fibonacci_binet(n)
    print(f"{n}\t{f_mat}\t{f_bin}")

# %% [markdown]
# ---
# ## (Bonus) Part 4 : Spectral Theorem Application (10 points)
#
#
# For a **symmetric** matrix, the eigenvectors are orthogonal and form an orthonormal basis.
#
# Given:
# $$S = \begin{bmatrix} 4 & 2 & 2 \\ 2 & 4 & 2 \\ 2 & 2 & 4 \end{bmatrix}$$
#
# 1. Verify that $S$ is symmetric
# 2. Find all eigenvalues and eigenvectors
# 3. Verify eigenvectors are orthogonal
# 4. Construct orthonormal matrix $Q$ and diagonal $\Lambda$ such that $S = Q\Lambda Q^T$
# 5. Use this to compute $S^{1/2}$ (matrix square root)

# %%
S = np.array([[4, 2, 2],
              [2, 4, 2],
              [2, 2, 4]])

# TODO:

# Task 1: Verify symmetric

# Task 2: Find eigenvalues and eigenvectors

# Task 3: Verify orthogonality

# Task 4: Construct Q and Λ

# Task 5: Compute S^(1/2)
